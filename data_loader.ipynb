# %%
import src.data.data_utils as data

dataset = data.HSI_dataset("apex")

# %%
from tifffile import imread

im = imread("/home/ids/edabier/HSU/SS-HSU_benchmark/datasets_raw/washington_dc/19920612_AVIRIS_IndianPine_Site3.tif")

# %%
data = io.loadmat("/home/ids/edabier/HSU/SS-HSU_benchmark/datasets_raw/Donnees labo avec GT/scene1/scene1_mixture1.mat")
y = torch.tensor(data["scene1_mixture1"])
data.keys()
y.shape
# print(data["Y"].shape, data["E"].shape, data["A"].shape, data["H"], data["W"], data["p"], data["L"], data["D"].shape, data["M"])
# Out:
# torch.Size([111, 132, 256])

# %%
import torch
import matplotlib.pyplot as plt
import scipy.io as io

dataset = "urban"
data = io.loadmat(f"../datasets/{dataset}.mat")
Y = torch.tensor(data["Y"])
plt.imshow(Y.reshape(Y.shape[0], int(Y.shape[1]**0.5), int(Y.shape[1]**0.5))[10,:,:])

# %%
# a = scipy.io.loadmat(f"/home/ids/edabier/HSU/datasets_raw/{dataset}/Urban.mat")
# a_gt = scipy.io.loadmat(f"/home/ids/edabier/HSU/datasets_raw/{dataset}/end6_groundTruth.mat")

# standard_data = {
#     'Y': a["X"],
#     'E': a_gt["M"],
#     'A': a_gt["A"]
# }

# scipy.io.savemat(f"/home/ids/edabier/HSU/datasets/{dataset}.mat", standard_data)
dataset = "urban"

a = scipy.io.loadmat(f"/home/ids/edabier/HSU/SS-HSU_benchmark/datasets/{dataset}.mat")
a['Y'].shape
# Out:
# (162, 94249)

# %% [markdown]
# ### Apex:
# - `apex_dataset.mat`: contains `Y` shape (285, 12100), `A` shape (4, 12100), `M` shape (285, 4), `M1`
#  shape (285, 4)
# *M = E and M1 = init_weight (?)*
#
#
# ### Cuprite:
# - `CupriteS1_R188.mat` contains: `Y` shape (188, 47500), `nRow`=250, `nCol`=190
# - `groundTruth_Cuprite_nEnd12.mat` contains: `waveLength` shape (1, 224), `M`: shape (224,12)
#
# ### Jasper:
# - `jasperRidge2_R198.mat` contains `nRow`=100, `nCol`=100, `Y` shape (198, 10000)
# - `end4.mat` contains `M` shape (198, 4), `A` shape (4, 10000)
#
# ### Samson:
# - `samson.mat` contains `V` shape (156, 9025), `nRow`=95, `nCol`=95
# - `end3.mat` contains `M` shape (156, 3), `A` shape (3, 9025)
#
# ### Urban:
# - `endmembers_urban.mat` contains `'donnees'`: shape (162,6)
# - `end6_groundTruth.mat` contains `A`: shape (6, 94249), `M`: shape (162, 6), `nEnd`= 6, `nRow`= 307, `nCol`= 307
# - `Urban.mat` contains `X`: shape (162, 94249)
