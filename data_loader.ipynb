# %%
import scipy.io

apex = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Apex/apex_dataset.mat")
apex_gt = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Apex/S_VCA_Apex_LS.mat")

cuprite = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Cuprite/CupriteS1_R188.mat")
cuprite_gt = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Cuprite/groundTruth_Cuprite_end12/groundTruth_Cuprite_nEnd12.mat")

jasper = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Jasper/jasperRidge2_R198.mat")
jasper_gt = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Jasper/S_VCA_Jasper_LS.mat")

samson = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Samson/samson.mat")
samson_gt = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Samson/S_VCA_Samson_LS.mat")

urban = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Urban/Urban.mat")
urban_gt = scipy.io.loadmat("/home/ids/edabier/HSU/datasets/Urban/end6_groundTruth.mat")

sets = {"apex": [apex, apex_gt], "cuprite": [cuprite, cuprite_gt], "jasper": [jasper, jasper_gt], "samson": [samson, samson_gt], "urban": [urban, urban_gt]}
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1021

# %%
jasper.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Region', 'SlectBands', 'nRow', 'nCol', 'nBand', 'Y', 'maxValue'])
