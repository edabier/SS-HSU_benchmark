# %%
# from huggingface_hub import hf_hub_download
# hf_hub_download(repo_id="JingtaoLi/HyperFree", filename="Ckpt/HyperFree-b.pth")
# Out:
# '/home/ids/edabier/.cache/huggingface/hub/models--JingtaoLi--HyperFree/snapshots/69fb1d0bfa05f928ae77730c8277ecda5a0fbfd8/Ckpt/HyperFree-b.pth'

# %%
import torch

if torch.cuda.is_available():
    dev = "cuda:0"
    torch.set_default_device(dev)
else:
    print(f"{torch.cuda.is_available()}")
    dev = "cpu"

# %%
model = torch.load("/home/ids/edabier/HSU/models/models--JingtaoLi--HyperFree/snapshots/69fb1d0bfa05f928ae77730c8277ecda5a0fbfd8/Ckpt/HyperFree-b.pth", weights_only=False, map_location=dev)
